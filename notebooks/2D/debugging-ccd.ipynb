# %% [markdown]
# # Finite differences Error

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
from sympy import *
init_printing()

vi_0 = [0.9999997944393129,  1.000390495717967]
vj_0 = [0.9999997944477195,  2.000390495717967]
vk_0 = [1.000000205623107, 1.000195221116208]
vi_1 = [1.000000114949107, 1.095136487530685]
vj_1 = [1.000000091688793, 2.095136487530685]
vk_1 = [0.999999888897309, 1.046585522643727]
vi_0 = np.append(vi_0, [0])
vj_0 = np.append(vj_0, [0])
vk_0 = np.append(vk_0, [0])

vi_1 = np.append(vi_1, [1])
vj_1 = np.append(vj_1, [1])
vk_1 = np.append(vk_1, [1])

# %%
fig, ax = plt.subplots()
polygon = np.array([vi_0, vj_0, vj_1, vi_1, vi_0])
line = np.array([vk_0, vk_1])
print(polygon.shape)
ax.plot(polygon[:,0], polygon[:,1], marker='o')
ax.plot(line[:,0], line[:,1], marker='o')
ax.autoscale()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# (5, 3)
